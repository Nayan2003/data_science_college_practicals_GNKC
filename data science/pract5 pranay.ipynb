# %%
#practical 5
#creation of data frame

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as pd

# %%
#q1
a1=pd.DataFrame(['mercury','venus','earth','mars','jupiter','saturn','neptune','pluto','uranus'])
a1
# Out:
#          0
# 0  mercury
# 1    venus
# 2    earth
# 3     mars
# 4  jupiter
# 5   saturn
# 6  neptune
# 7    pluto
# 8   uranus

# %%
#q2
a2=pd.DataFrame([["jan",31],["feb",28],["march",31],["april",30],["may",31],["june",30],["july",31],["august",31],["sept",30],["oct",31],["novem",30],["dec",31]])
a2
# Out:
#          0   1
# 0      jan  31
# 1      feb  28
# 2    march  31
# 3    april  30
# 4      may  31
# 5     june  30
# 6     july  31
# 7   august  31
# 8     sept  30
# 9      oct  31
# 10   novem  30
# 11     dec  31

# %%
#Q3
A3=pd.Series(["mumbai","gandhinagar","hyderabad","panji","kolkata"],index=['maharashtra','gujrat','andhra pradesh','goa','west bengal'])
states=pd.DataFrame(A3)
states
# Out:
#                           0
# maharashtra          mumbai
# gujrat          gandhinagar
# andhra pradesh    hyderabad
# goa                   panji
# west bengal         kolkata

# %%
#q4
english=np.array([45,60,75,90,100])
hindi=np.array([60,57,78,78,81])
sci=np.array([35,45,55,78,91])
soci=np.array([48,67,72,45,68])
maths=np.array([68,73,78,84,90])
names=np.array(['pranay','shubham','riya','sandhya','kanishka'])
marks=pd.DataFrame([names,english,hindi,sci,soci,maths])
marks
# Out:
#         0        1     2        3         4
# 0  pranay  shubham  riya  sandhya  kanishka
# 1      45       60    75       90       100
# 2      60       57    78       78        81
# 3      35       45    55       78        91
# 4      48       67    72       45        68
# 5      68       73    78       84        90

# %%
#q.5
a4={'capital':['kabul','islamabad','kathmadu','dhakka','bejing']}
a4
country=pd.DataFrame(a4,index=["afganistan","pakistan","nepal","bangladesh","china"])
country
# Out:
#               capital
# afganistan      kabul
# pakistan    islamabad
# nepal        kathmadu
# bangladesh     dhakka
# china          bejing
